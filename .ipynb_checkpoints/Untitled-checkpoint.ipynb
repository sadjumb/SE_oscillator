# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def bd(lambda_, x):
  x_array = []
  lambda_array = []
  for i in lambda_:
    for j in x:
      tmp = []
      x0 = j
      for z in range(400):
        x0 = i*x0/(1+x0**3)
        if z > 300:
          tmp.append(x0)
      x_array.append(tmp)
      lambda_array.append(i)
  plt.xlabel('λ')
  plt.ylabel('x*')
  plt.plot(lambda_array, x_array, 'r,')

# %%
lambda_ = np.linspace(0, 30, 300)
x = np.linspace(0, 20, 21)
bd(lambda_, x)

# %%
lambda_ = np.linspace(0, 500, 5000)
x = np.linspace(0, 20, 21)
bd(lambda_, x)

# %%
lambda_ = np.linspace(0, 2000, 20000)
x = np.linspace(0, 20, 21)
bd(lambda_, x)
