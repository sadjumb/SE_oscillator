# %%
import numpy as np
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from scipy.linalg import solve

# %% [markdown]
# def pendula(A, B, D):
#     def rhs(t, X):
#         y1, y2, k1, k2,= X
#         return (k1, k2, (D*y2 - y1)/(A - D**2), -(D*(D*y2 - y1)/(A - D**2) + y2)/B)
#     return rhs

# %% [markdown]
# f = pendula(1,1,1)
# integrate.RK45(f, 0, (1,1,1,1), 5)
# integrate.solve_ode(f, (0, 5), (1,1,1,1), "RK45")

# %%
def Alpha(l, c1, c2):
    return 1/(l * np.sqrt(c1 * c2))
def W1(l, l1, c1, a):
    return c1 * (l + l1) * a
def W2(l, l2, c2, a):
    return c2 * (l + l2) * a

# %%
def k(w1, w2, a):
    k1 = ((w1 + w2) + np.sqrt(pow(w1 - w2, 2) + 4 * pow(a, 2))) / (2*(w1*w2 - pow(a, 2)))
    k2 = ((w1 + w2) - np.sqrt(pow(w1 - w2, 2) + 4 * pow(a, 2))) / (2*(w1*w2 - pow(a, 2)))
    print(f"k1 = {k1}")
    print(f"k2 = {k2}")
    return k1, k2

def omega_w(w2, a):
    def omega(w1):
        return np.sqrt(k(w1, w2, a))
    return omega

# %%
def plot_ow(w2, a, left, right):
    plt.close()
    func = omega_w(w2, a)
    x = []
    y = []
    time = np.linspace(left, right, 100)
    for i in time:
        y.append(func(i)[0])
    plt.grid(True)
    plt.plot(time, y)

# %%
L = 1 #const
C1 = 1 #const
C2 = 1 #const
L1 = 1
a = Alpha(L, C1, C2)

print(f"alpha = {a}")

w2 = W2(L, L1, C1, a)
print(f"w2 = {w2}")
plot_ow(w2, a, 1, 20)
# Out:
# alpha = 1.0
# w2 = 2.0
# k1 = 2.618033988749895
# k2 = 0.3819660112501051
# k1 = 1.9326676302677355
# k2 = 0.3739017127979585
# k1 = 1.5490956958600188
# k2 = 0.3651900184256955
# k1 = 1.3061162758713523
# k2 = 0.35585555511456335
# k1 = 1.1401023553310414
# k2 = 0.34595342156138886
# k1 = 1.0208311417280354
# k2 = 0.3355702423550096
# k1 = 0.9320601971261087
# k2 = 0.32482053681884565
# k1 = 0.864243813782963
# k2 = 0.31383837799785896
# k1 = 0.8113780764487221
# k2 = 0.30276584414681135
# k1 = 0.7694836716473393
# k2 = 0.29174081814857905
# k1 = 0.7358147516698943
# k2 = 0.2808867097079762
# k1 = 0.7084176625741915
# k2 = 0.2703057416811276
# k1 = 0.685869790197924
# k2 = 0.2600761557480219
# k1 = 0.667116630374691
# k2 = 0.2502526782256462
# k1 = 0.6513654239201478
# k2 = 0.2408691244158268
# k1 = 0.6380131196891797
# k2 = 0.23194203726149293
# k1 = 0.6265961933928326
# k2 = 0.22347452796501738
# k1 = 0.6167549536111955
# k2 = 0.21545981148947557
# k1 = 0.6082077559456093
# k2 = 0.20788419807737935
# k1 = 0.6007321513038462
# k2 = 0.2007294808520613
# k1 = 0.5941509683548656
# k2 = 0.1939747592353557
# k1 = 0.5883219505117079
# k2 = 0.18759778192976376
# k1 = 0.5831299784220707
# k2 = 0.18157590393087045
# k1 = 0.5784811885452704
# k2 = 0.17588674567877893
# k1 = 0.574298492552328
# k2 = 0.17050862910939305
# k1 = 0.5705181389541203
# k2 = 0.061607154680664335
# k1 = 0.517956068374561
# k2 = 0.06089069811158108
# k1 = 0.5177130564671096
# k2 = 0.06019062625243717
# k1 = 0.5174765059849038
# k2 = 0.059506386705609406
# k1 = 0.5172461636594419
# k2 = 0.05883745146505866
# k1 = 0.5170217892365485
# k2 = 0.058183315594809715
# k1 = 0.5168031546541452
# k2 = 0.05754349599169442
# k1 = 0.5165900432813564
# k2 = 0.0569175302262171
# k1 = 0.5163822492137005
# k2 = 0.05630497545590303
# k1 = 0.5161795766196144
# k2 = 0.05570540740594464
# k1 = 0.5159818391340188
# k2 = 0.05511841941237585
# k1 = 0.515788859295031
# k2 = 0.05454362152338322
# k1 = 0.5156004680202985
# k2 = 0.05398063965470856
# k1 = 0.5154165041197479
# k2 = 0.053429114795412055
# k1 = 0.5152368138418402
# k2 = 0.0528887022605546
# k1 = 0.515061250450679
# k2 = 0.05235907098762128
# k1 = 0.5148896738315623
# k2 = 0.05183990287374915
# k1 = 0.5147219501227742
# k2 = 0.05133089215104487
# k1 = 0.5145579513716092
# k2 = 0.05083174479747928
# k1 = 0.5143975552127938
# k2 = 0.050342177981033055
# k1 = 0.5142406445676261
# k2 = 0.049861919534938015

# %%
L = 1
C1 = 1 
C2 = 2
L1 = 4
a = Alpha(L, C1, C2)

print(f"alpha = {a}")

w2 = W2(L, L1, C1, a)
print(f"w2 = {w2}")
plot_ow(w2, a, 0, 10)
# Out:
# alpha = 0.7071067811865475
# w2 = 3.5355339059327373
# k1 = -7.343420458864693
# k2 = 0.27235264699921663
# k1 = -25.724639749815662
# k2 = 0.2720779530094393
# k1 = 17.173096666277594
# k2 = 0.271789094442658
# k1 = 6.44664499515927
# k2 = 0.27148499959772154
# k1 = 3.9717870117538725
# k2 = 0.2711644921430926
# k1 = 2.8720731791964287
# k2 = 0.2708262789882846
# k1 = 2.2506694006856254
# k2 = 0.2704689366108621
# k1 = 1.8513466962656422
# k2 = 0.27009089564748334
# k1 = 1.5731691718010883
# k2 = 0.26969042354245454
# k1 = 1.3683266818278375
# k2 = 0.2692656050360318
# k1 = 1.2112476379576564
# k2 = 0.26881432027033464
# k1 = 1.0870164719432713
# k2 = 0.268334220297875
# k1 = 0.9863473125537542
# k2 = 0.2678226998030911
# k1 = 0.903157517797196
# k2 = 0.2672768669005187
# k1 = 0.8332966918867929
# k2 = 0.2666935099678989
# k1 = 0.7738364504454273
# k2 = 0.26606906162734173
# k1 = 0.722652081752192
# k2 = 0.26539956022800637
# k1 = 0.678165124846236
# k2 = 0.2646806095431538
# k1 = 0.6391790072087967
# k2 = 0.26390733791561116
# k1 = 0.6047707277913156
# k2 = 0.26307435882068725
# k1 = 0.574217489464168
# k2 = 0.2621757358230177
# k1 = 0.5469457930212239
# k2 = 0.2612049562414301
# k1 = 0.5224953511646551
# k2 = 0.2601549195443907
# k1 = 0.5004930068130546
# k2 = 0.259017948571894
# k1 = 0.4806335395360628
# k2 = 0.2577858340164317
# k1 = 0.4626652943906629
# k2 = 0.2564499249283206
# k1 = 0.4463792332595823
# k2 = 0.25500127981644255
# k1 = 0.43160044129163583
# k2 = 0.25343089333243296
# k1 = 0.4181814096830172
# k2 = 0.25173001132767814
# k2 = 0.11924759998904634
# k1 = 0.2911623410717316
# k2 = 0.11785695243699318
# k1 = 0.2909944400046065
# k2 = 0.11649729066945785
# k1 = 0.2908330623525516
# k2 = 0.115167650083498
# k1 = 0.29067784158117094
# k2 = 0.11386710130473307
# k1 = 0.2905284376611387
# k2 = 0.11259474901024762
# k1 = 0.29038453475376746
# k2 = 0.1113497307466848
# k1 = 0.29024583913096813
# k2 = 0.11013121575342281
# k1 = 0.2901120773028327
# k2 = 0.10893840379868443
# k1 = 0.289982994329445
# k2 = 0.1077705240347425
# k1 = 0.2898583522964409
# k2 = 0.10662683387699147
# k1 = 0.289737928936357
# k2 = 0.1055066179105071
# k1 = 0.28962151637999095
# k2 = 0.1044091868267744
# k1 = 0.28950892002388623
# k2 = 0.10333387639248952
# k1 = 0.2893999575017037
# k2 = 0.10228004645170959
# k1 = 0.2892944577486706
# k2 = 0.10124707996210949
# k1 = 0.2891922601495485
# k2 = 0.10023438206568787
# k1 = 0.28909321376165503
# k2 = 0.0992413791939283
# /tmp/ipykernel_375/1001462003.py:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(k(w1, w2, a))

# %%
L = 0.01
C1 = 0.1
C2 = 3 
L1 = 2
a = Alpha(L, C1, C2)

print(f"alpha = {a}")

w2 = W2(L, L1, C1, a)
print(f"w2 = {w2}")
plot_ow(w2, a, 2, 20)
# Out:
# alpha = 0.005477225575051662
# w2 = 0.20099999999999998
# k1 = 4.975537168884488
# k2 = 0.4999958310906357
# k1 = 4.975499276806002
# k2 = 0.45833015182406583
# k1 = 4.975467756393943
# k2 = 0.42307444010908946
# k1 = 4.975441125175985
# k2 = 0.3928551679613178
# k1 = 4.975418327472742
# k2 = 0.36666507012613153
# k1 = 4.9753985911221905
# k2 = 0.3437486909989385
# k1 = 4.975381338290121
# k2 = 0.32352832518499586
# k1 = 4.975366127956502
# k2 = 0.30555464372048263
# k1 = 4.975352617686489
# k2 = 0.2894729115652334
# k1 = 4.975340537541433
# k2 = 0.2749993395928277
# k1 = 4.97532967185825
# k2 = 0.2619041930049815
# k1 = 4.975319846261099
# k2 = 0.2499995064510656
# k1 = 4.975310918232471
# k2 = 0.23913000384240288
# k1 = 4.975302770155377
# k2 = 0.22916628817684243
# k1 = 4.975295304102716
# k2 = 0.21999966578186705
# k1 = 4.975288437882521
# k2 = 0.21153816494745686
# k1 = 4.975282101999567
# k2 = 0.20370343929660262
# k1 = 4.9752762372948505
# k2 = 0.19642833471196944
# k1 = 4.975270793092814
# k2 = 0.18965495965194548
# k1 = 4.975265725733312
# k2 = 0.18333314139986812
# k1 = 4.975260997398224
# k2 = 0.17741918110112634
# k1 = 4.975256575165956
# k2 = 0.17187484222892493
# k1 = 4.975252430243811
# k2 = 0.166666522963981
# k1 = 4.97524853734038
# k2 = 0.16176457462383878
# k1 = 4.97524487414904
# k2 = 0.15714273693210132
# k1 = 4.9752414209202485
# k2 = 0.15277766740888013
# k1 = 4.975238160105351
# k2 = 0.14864854707586236
# k1 = 4.975235076058305
# k2 = 0.14473674841813391
# k1 = 4.975232154784635
# k2 = 0.14102555442853287
# k1 = 4.975229383729115
# k2 = 0.13749991979514922
# k1 = 4.975226751595385
# k2 = 0.13414626703682897
# k1 = 4.97522424819203
# k2 = 0.13095231176205513
# k1 = 4.97522186430071
# k2 = 0.127906912310206
# k1 = 4.9752195915627215
# k2 = 0.12499993989619891
# k1 = 4.975217422381089
# k2 = 0.122222166069116
# k1 = 4.975215349835715
# k2 = 0.11956516485008671
# k1 = 4.975213367609649
# k2 = 0.11702122736316518
# k1 = 4.975211469924766
# k2 = 0.11458328713731117
# k1 = 4.975209651485521
# k2 = 0.1122448545550416
# k1 = 4.975207907429598
# k2 = 0.10999995916721748
# k1 = 4.975206233284493
# k2 = 0.1078430987943086
# k1 = 4.975204624929222
# k2 = 0.1057691945005733
# k1 = 4.975203078560443
# k2 = 0.10377355066548667
# k1 = 4.975201590662442
# k2 = 0.10185181949166623
# k1 = 4.975200157980436
# k2 = 0.0999999693846503
# k1 = 4.975198777496814
# k2 = 0.09821425672055042
# k1 = 4.975197446409921
# k2 = 0.09649120058552083
# k1 = 4.975196162115068
# k2 = 0.09482756012838489
# k1 = 4.975194922187541
# k2 = 0.09322031421637289
# k1 = 4.975193724367301
# k2 = 0.0916666431252901
# k1 = 4.975192566545249
# k2 = 0.09016391203064057
# k1 = 4.975191446750828
# k2 = 0.08870965609638659
# k1 = 4.9751903631408325
# k2 = 0.08730156698382115
# k1 = 4.975189313989283
# k2 = 0.08593748062523245
# k1 = 4.975188297678255
# k2 = 0.08461536612614978
# k1 = 4.975187312689548
# k2 = 0.08333331567647756
# k1 = 4.975186357597126
# k2 = 0.08208953536510412
# k1 = 4.975185431060222
# k2 = 0.08088233680498985
# k1 = 4.975184531817062
# k2 = 0.07971012948650252
# k1 = 4.975183658679131
# k2 = 0.07857141378618357
# k1 = 4.975182810525932
# k2 = 0.0774647745663219
# k1 = 4.97518198630019
# k2 = 0.07638887530789297
# k1 = 4.975181185003454
# k2 = 0.07534245272572375
# k1 = 4.975180405692064
# k2 = 0.07432431182026658
# k1 = 4.975179647473438
# k2 = 0.07333332132522655
# k1 = 4.975178909502668
# k2 = 0.07236840951459082
# k1 = 4.97517819097938
# k2 = 0.071428560336378
# k1 = 4.975177491144829
# k2 = 0.07051280984379625
# k1 = 4.97517680927924
# k2 = 0.06962024289744709
# k1 = 4.9751761446993275
# k2 = 0.06874999011486745
# k1 = 4.975175496756015
# k2 = 0.06790122504603067
# k1 = 4.975174864832324
# k2 = 0.06707316155551533
# k1 = 4.97517424834141
# k2 = 0.06626505139391788
# k1 = 4.975173646724746
# k2 = 0.06547618194273516
# k1 = 4.9751730594504355
# k2 = 0.06470587411842922
# k1 = 4.975172486011645
# k2 = 0.06395348042272221
# k1 = 4.975171925925142
# k2 = 0.06321838312735326
# k1 = 4.975171378729942
# k2 = 0.06249999258260202
# k1 = 4.975170843986035
# k2 = 0.06179774563984148
# k1 = 4.975170321273213
# k2 = 0.06111110417925882
# k1 = 4.975169810189967
# k2 = 0.06043955373464522
# k1 = 4.975169310352454
# k2 = 0.059782602207874555
# k1 = 4.975168821393542
# k2 = 0.059139778666320995
# k1 = 4.975168342961908
# k2 = 0.058510632217033294
# k1 = 4.975167874721194
# k2 = 0.05789473095201613
# k1 = 4.975167416349221
# k2 = 0.057291660959432514
# k1 = 4.975166967537249
# k2 = 0.056701025395963896
# k1 = 4.975166527989284
# k2 = 0.05612244361597257
# k1 = 4.9751660974214245
# k2 = 0.055555550353433576
# k1 = 4.975165675561255
# k2 = 0.05499999495295601
# k1 = 4.975165262147267
# k2 = 0.054455440646485685
# k1 = 4.97516485692832
# k2 = 0.05392156387255066
# k1 = 4.97516445966313
# k2 = 0.05339805363517037
# k1 = 4.9751640701197966
# k2 = 0.05288461089973965
# k1 = 4.975163688075345
# k2 = 0.05238094802344573
# k1 = 4.975163313315305
# k2 = 0.05188678821791439
# k1 = 4.975162945633307
# k2 = 0.051401865041997986
# k1 = 4.975162584830704
# k2 = 0.05092592192273439
# k1 = 4.975162230716212
# k2 = 0.05045871170267993
# k1 = 4.975161883105577
# k2 = 0.04999999621193073

# %% [markdown]
# # Results:
#     от l1 при константном alpha изменения малы.

# %% [markdown]
# # 6 задача: построить зависимости q1,2(t), соответствующие нормальным колебаниям

# %%
def solve_matrix(omega, w1, w2, alpha):
    left = np.array(
        [
            [-omega**2 * w1 + 1, -alpha * omega**2],
            [-alpha*omega**2,    -omega**2 * w2 + 1]
        ]
    )
    
    right = np.array([0, 0])
    return np.linalg.solve(left, right)

def beta(b, w1, omega, alpha):
    return b * alpha * pow(omega, 2) / (1 - w1 * pow(omega, 2))

# %%
def solution(c1, c2, omega, time): #return vector 2x1, q1, q2
    q1 = []
    q2 = []
    for i in time:
        q1.append(c1[0] * np.cos(omega[0] * i) + c2[0] * np.cos(omega[1] * i))
        q2.append(c1[1] * np.cos(omega[0] * i) + c2[1] * np.cos(omega[1] * i))
    return q1, q2
def coeff(c1, c2, omega, condition, t0): # Ax = condition, поиск c1, c2
    m = np.array(
        [
            [c1[0] * np.cos(omega[0] * t0), c2[0] * np.cos(omega[1] * t0)],
            [c1[1] * np.cos(omega[0] * t0), c2[1] * np.cos(omega[1] * t0)]
        ]
    )
    print(condition)
    return np.linalg.solve(m, condition)

# %%
L = 2 #const
C1 = 3 #const
C2 = 4 #const
L1 = 1
L2 = 2
a = Alpha(L, C1, C2)
print(f"alpha = {a}")

w2 = W2(L, L1, C1, a)
print(f"w2 = {w2}")
w1 = W1(L, L2, C2, a)
print(f"w1 = {w1}")
omega = omega_w(w2, a)(w1)
print(f"omega = {omega}")

c1 = np.array([beta(1, w1, omega[0], a), 1])
c2 = np.array([beta(1, w1, omega[1], a), 1])
print(f"a = {c1}")
print(f"b = {c2}")

#coeff(c1, c2, omega, [1, 0], 0)
res_coef = coeff(c1, c2, omega, (1, 0), 1)
print(f"coeff = {res_coef}")
c1 = c1 * res_coef[0]
c2 = c2 * res_coef[1]
print(f"c1 = {c1}")
print(f"c2 = {c2}")
# Out:
# alpha = 0.14433756729740646
# w2 = 1.2990381056766582
# w1 = 2.3094010767585034
# k1 = 0.7819690965334324
# k2 = 0.4292552444238244
# omega = [0.88429017 0.65517574]
# a = [-0.14005494  1.        ]
# b = [7.14005494 1.        ]
# (1, 0)
# coeff = [-0.21671218  0.17322927]
# c1 = [ 0.03035161 -0.21671218]
# c2 = [1.23686648 0.17322927]

# %%
time = np.linspace(0,300, 300)
res = solution(c1, c2, omega, time)
plt.plot(time, res[1])
plt.plot(time, res[0])
